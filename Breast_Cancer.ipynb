# %% [markdown]
# # Breast Cancer Classifire
#
# ### This Model Can Classify That Wether You Have Or a Posibility To Have a Breast_Cancer

# %% [markdown]
# ### Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ### Import And Desplay The Data

# %%
data = pd.read_csv('Breast_Cancer.csv')
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
data.shape
# Out:
# (569, 33)

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Find The Missing Values

# %%
data.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %% [markdown]
# **-> There is no null values**

# %% [markdown]
# ### Encode the Catagoricle data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['diagnosis'] = le.fit_transform(data['diagnosis'])

# %%
data.head()
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302          1        17.99         10.38          122.80     1001.0
# 1    842517          1        20.57         17.77          132.90     1326.0
# 2  84300903          1        19.69         21.25          130.00     1203.0
# 3  84348301          1        11.42         20.38           77.58      386.1
# 4  84358402          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# ## Feture Selection

# %% [markdown]
# ### Correletion and Heat Map

# %%
data.corr()
# Out:
#                                id  diagnosis  radius_mean  texture_mean  \
# id                       1.000000   0.039769     0.074626      0.099770
# diagnosis                0.039769   1.000000     0.730029      0.415185
# radius_mean              0.074626   0.730029     1.000000      0.323782
# texture_mean             0.099770   0.415185     0.323782      1.000000
# perimeter_mean           0.073159   0.742636     0.997855      0.329533
# area_mean                0.096893   0.708984     0.987357      0.321086
# smoothness_mean         -0.012968   0.358560     0.170581     -0.023389
# compactness_mean         0.000096   0.596534     0.506124      0.236702
# concavity_mean           0.050080   0.696360     0.676764      0.302418
# concave points_mean      0.044158   0.776614     0.822529      0.293464
# symmetry_mean           -0.022114   0.330499     0.147741      0.071401
# fractal_dimension_mean  -0.052511  -0.012838    -0.311631     -0.076437
# ...

# %%
plt.figure(figsize=(12,10))
g = sns.heatmap(data.corr(),annot = True , cmap = "brg")

# %%
X  = data.drop('diagnosis',axis=1)
y = data['diagnosis']

# %% [markdown]
# ### Drop The Highly Correlated columns

# %%
def correlation(dataset, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if(corr_matrix.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]  # getting the name of column
                col_corr.add(colname)
    return col_corr

# %%
corr_features = correlation(X, 0.9)
len(set(corr_features))
# Out:
# 10

# %%
corr_features
# Out:
# {'area_mean',
#  'area_se',
#  'area_worst',
#  'concave points_mean',
#  'concave points_worst',
#  'perimeter_mean',
#  'perimeter_se',
#  'perimeter_worst',
#  'radius_worst',
#  'texture_worst'}

# %%
X.drop(corr_features,axis=1,inplace=True)
X.head()
# Out:
#          id  radius_mean  texture_mean  smoothness_mean  compactness_mean  \
# 0    842302        17.99         10.38          0.11840           0.27760
# 1    842517        20.57         17.77          0.08474           0.07864
# 2  84300903        19.69         21.25          0.10960           0.15990
# 3  84348301        11.42         20.38          0.14250           0.28390
# 4  84358402        20.29         14.34          0.10030           0.13280
#
#    concavity_mean  symmetry_mean  fractal_dimension_mean  radius_se  \
# 0          0.3001         0.2419                 0.07871     1.0950
# 1          0.0869         0.1812                 0.05667     0.5435
# 2          0.1974         0.2069                 0.05999     0.7456
# 3          0.2414         0.2597                 0.09744     0.4956
# 4          0.1980         0.1809                 0.05883     0.7572
#
#    texture_se  ...  concavity_se  concave points_se  symmetry_se  \
# ...

# %%
X.shape
# Out:
# (569, 22)

# %% [markdown]
# ### Drop The Use Less Columns

# %%
X.drop(['id','Unnamed: 32'],axis=1,inplace=True)

# %%
X.shape
# Out:
# (569, 20)

# %%
X.head()
# Out:
#    radius_mean  texture_mean  smoothness_mean  compactness_mean  \
# 0        17.99         10.38          0.11840           0.27760
# 1        20.57         17.77          0.08474           0.07864
# 2        19.69         21.25          0.10960           0.15990
# 3        11.42         20.38          0.14250           0.28390
# 4        20.29         14.34          0.10030           0.13280
#
#    concavity_mean  symmetry_mean  fractal_dimension_mean  radius_se  \
# 0          0.3001         0.2419                 0.07871     1.0950
# 1          0.0869         0.1812                 0.05667     0.5435
# 2          0.1974         0.2069                 0.05999     0.7456
# 3          0.2414         0.2597                 0.09744     0.4956
# 4          0.1980         0.1809                 0.05883     0.7572
#
#    texture_se  smoothness_se  compactness_se  concavity_se  concave points_se  \
# 0      0.9053       0.006399         0.04904       0.05373            0.01587
# ...

# %%
data['compactness_mean'].max()
# Out:
# 0.3454

# %% [markdown]
# ## Fit And Train The Model

# %% [markdown]
# ### Splite The Data In Train And Test

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X, y, test_size = 0.2, random_state = 1)

# %%
X_train.shape,y_train.shape
# Out:
# ((455, 20), (455,))

# %%
X_test.shape,y_test.shape
# Out:
# ((114, 20), (114,))

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 455 entries, 408 to 37
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   radius_mean              455 non-null    float64
#  1   texture_mean             455 non-null    float64
#  2   smoothness_mean          455 non-null    float64
#  3   compactness_mean         455 non-null    float64
#  4   concavity_mean           455 non-null    float64
#  5   symmetry_mean            455 non-null    float64
#  6   fractal_dimension_mean   455 non-null    float64
#  7   radius_se                455 non-null    float64
#  8   texture_se               455 non-null    float64
#  9   smoothness_se            455 non-null    float64
#  10  compactness_se           455 non-null    float64
#  11  concavity_se             455 non-null    float64
#  12  concave points_se        455 non-null    float64
# ...

# %% [markdown]
# ## Train The Model

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators=100,criterion='gini',max_depth=6,max_features='auto')
classifier.fit(X_train,y_train)
# Out:
# RandomForestClassifier(max_depth=6)

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score
confusion_matrix(y_test,y_pred)
# Out:
# array([[71,  1],
#        [ 8, 34]], dtype=int64)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9210526315789473

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.99      0.94        72
#            1       0.97      0.81      0.88        42
#
#     accuracy                           0.92       114
#    macro avg       0.94      0.90      0.91       114
# weighted avg       0.93      0.92      0.92       114

# %%
#import pickle
import pickle
pkl_file = open("Breast_Cancer.pkl",'wb')
pickle.dump(classifier,pkl_file)
pkl_file.close()
